# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ufc-master.csv')

# %%
df
# Out:
#                   R_fighter              B_fighter  R_odds  B_odds  \
# 0     Alexander Volkanovski           Brian Ortega  -180.0     155
# 1      Valentina Shevchenko          Lauren Murphy -1375.0     800
# 2                 Nick Diaz          Robbie Lawler   140.0    -160
# 3            Curtis Blaydes  Jairzinho Rozenstruik  -380.0     290
# 4           Jessica Andrade       Cynthia Calvillo  -220.0     180
# ...                     ...                    ...     ...     ...
# 4880           Duane Ludwig          Darren Elkins  -155.0     135
# 4881            John Howard         Daniel Roberts  -210.0     175
# 4882         Brendan Schaub          Chase Gormley  -260.0     220
# 4883            Mike Pierce          Julio Paulino  -420.0     335
# 4884           Eric Schafer            Jason Brilz   140.0    -160
#
#             R_ev   B_ev        date                   location country Winner  \
# 0      55.555556  155.0  2021-09-25     Las Vegas, Nevada, USA     USA    Red
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                R_fighter              B_fighter  R_odds  B_odds        R_ev  \
# 0  Alexander Volkanovski           Brian Ortega  -180.0     155   55.555556
# 1   Valentina Shevchenko          Lauren Murphy -1375.0     800    7.272727
# 2              Nick Diaz          Robbie Lawler   140.0    -160  140.000000
# 3         Curtis Blaydes  Jairzinho Rozenstruik  -380.0     290   26.315789
# 4        Jessica Andrade       Cynthia Calvillo  -220.0     180   45.454545
#
#     B_ev        date                location country Winner  title_bout  \
# 0  155.0  2021-09-25  Las Vegas, Nevada, USA     USA    Red        True
# 1  800.0  2021-09-25  Las Vegas, Nevada, USA     USA    Red        True
# 2   62.5  2021-09-25  Las Vegas, Nevada, USA     USA   Blue       False
# 3  290.0  2021-09-25  Las Vegas, Nevada, USA     USA    Red       False
# 4  180.0  2021-09-25  Las Vegas, Nevada, USA     USA    Red       False
#
#         weight_class  gender  no_of_rounds  B_current_lose_streak  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4885 entries, 0 to 4884
# Columns: 119 entries, R_fighter to b_ko_odds
# dtypes: bool(1), float64(58), int64(46), object(14)
# memory usage: 4.4+ MB

# %%
df.describe()
# Out:
#             R_odds       B_odds         R_ev         B_ev  no_of_rounds  \
# count  4884.000000  4885.000000  4884.000000  4885.000000   4885.000000
# mean   -117.730344    66.151689    94.764839   167.126182      3.181986
# std     268.803044   247.639322    82.687831   136.971045      0.571507
# min   -1700.000000 -1200.000000     5.882353     8.333333      3.000000
# 25%    -255.000000  -145.000000    39.215686    68.965517      3.000000
# 50%    -150.000000   130.000000    66.666667   130.000000      3.000000
# 75%     126.250000   220.000000   126.250000   220.000000      3.000000
# max     775.000000  1300.000000   775.000000  1300.000000      5.000000
#
#        B_current_lose_streak  B_current_win_streak       B_draw  \
# count            4885.000000           4885.000000  4885.000000
# mean                0.477175              0.875537     0.010645
# std                 0.769066              1.311944     0.108454
# ...
